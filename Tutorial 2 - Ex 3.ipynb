# %%
import numpy as np

# %%
m=1
s=1

a=1
n=1

size = 10000 

x1 = np.random.normal(loc=m, scale=s, size=size)
x2 = x1 + np.random.normal(loc=0, scale=n, size=size)

# %%
x = np.vstack((x1, x2))

# %%
import matplotlib.pyplot as plt
plt.plot(x1, x2, linewidth=0, marker='.')
plt.show()

# %%
np.cov(x)
# Out:
# array([[0.99177604, 1.01519216],
#        [1.01519216, 2.04392359]])

# %%
np.mean(x[0])
# Out:
# 1.0018585024830264

# %%
np.mean(x[1])
# Out:
# 1.0111968792976957
