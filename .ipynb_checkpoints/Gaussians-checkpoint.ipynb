# %%
import numpy as np

# %%
mu = 2.0
sigma = 3.0
delta = sigma / 100.0
xx = np.arange(mu - 10*sigma, mu + 10*sigma, delta)
integrand = np.exp(-0.5*(xx - mu)**2/sigma**2)
Zapprox = np.sum(integrand*delta)
print("Zapprox = %g" % Zapprox)
# Out:
# Zapprox = 7.51988

# %%
Zapprox * 1./(np.sqrt(2*3.14)*sigma)
# Out:
# 1.0002535751093153

# %%
import numpy as np
from matplotlib import pyplot as plt

N = int(1e6) # 1e6 is a float, numpy wants int arguments
xx = np.random.randn(N)
hist_stuff = plt.hist(xx, bins=100)
plt.show()
# To check the mean and variance:

print('empirical_mean = %g' % np.mean(xx)) # or xx.mean()
print('empirical_var = %g' % np.var(xx))   # or xx.var()
# Out:
# <img src="data:image/png;base64,..." width="640">
# empirical_mean = -0.0007114
# empirical_var = 0.999576

# %%
# You should understand how to plot a theoretical prediction of this histogram shape. Fill in the parts marked TODO below:

bin_centres = 0.5*(hist_stuff[1][1:] + hist_stuff[1][:-1])
# Fill in an expression to evaluate the PDF at the bin_centres.
# To square every element of an array, use **2
pdf = (1/np.sqrt(np.pi*2)) * np.exp(-0.5 * np.square(bin_centres))
bin_width = bin_centres[1] - bin_centres[0]
predicted_bin_heights = N * bin_width * pdf # pdf needs scaling correctly
# Finally, plot the theoretical prediction over the histogram:
plt.plot(bin_centres, predicted_bin_heights, '-r')
plt.show()

# %%
xx = [np.random.poisson(size=100).sum() for i in range(100000)]
plt.hist(xx, bins=100)
plt.show()
# hist_stuff = plt.hist(xx, bins=100)

# %%
c=0
sz=10000
runs=10000
stds=2
for i in range(runs):
    xx = np.random.binomial(1, 0.3, size=sz)
    mn = xx.mean() - stds*xx.std()/np.sqrt(sz)
    mx = xx.mean() + stds*xx.std()/np.sqrt(sz)
    if ((mn <= 0.3) and (mx >=0.3)):
#         print('%.3f %.3f' % (mn, mx))
        c+=1
c/runs
# Out:
# 0.9564

# %%
from mpl_toolkits.mplot3d import Axes3D

N = int(2022); D = 3
X = np.random.randn(N, D)
# X = np.random.laplace(size=N).reshape((-1,3))
# %matplotlib


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2], c='b', marker='.')

# plt.axis('square')
plt.show()
# Out:
# Using matplotlib backend: nbAgg
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Covariance

# %%
N = int(10000); D = 3
np.random.seed(1)
X = np.random.randn(D, N)

# %%
X.shape
# Out:
# (3, 10000)

# %%
X[:,0]
# Out:
# array([ 1.62434536, -0.12247391, -1.93156389])

# %%
Ex = np.mean(X, axis=1, keepdims=True)

# %%
ExEx = Ex * Ex.T
ExEx

# %%
Exx = X@X.T/N
Exx

# %%
cov = (Exx - ExEx)
cov

# %%
npcov = np.cov(X, bias=False)
npcov * (N-1)/N

# %%
import numpy as np
np.random.seed(1)
D = 3
b1 = np.random.rand(D)
b2 = np.random.rand(D)
X = np.column_stack([b1, b2])
X

# %%
X.conj()

# %%
X -= X.mean(axis=0) 
fact = D - 1 
by_hand = np.dot(X, X.T) / fact
print(by_hand)
# [[ 0.04735338  0.01242557]
#  [ 0.01242557  0.07669083]]

# %%
using_cov = np.cov(X)
using_cov
# assert np.allclose(by_hand, using_cov)

# %%
A = np.array([[1,0],[1,0]])

# %%
A
# Out:
# array([[1, 0],
#        [1, 0]])

# %%
np.dot(A,A.T)

# %%
S=np.invert(np.dot(A,A.T))

# %%
b=np.array([5,4])

# %%
np.dot(b.T,S)
# Out:
# array([-18, -18])

# %%
np.dot(np.dot(b.T,S),b)
# Out:
# -162

# %% [markdown]
# # Plot

# %%
Sm1 = A
Sm1
# Out:
# array([[1, 0],
#        [1, 0]])

# %%
# Out:
# 0.0

# %%
def gauss2d(Sm1, y):
    np.linalg.det(A)
    1/np.det
# Out:
#   File "<ipython-input-88-7c30d6b2df18>", line 1
#     def gauss2d(Sm1, y):
#                         ^
# SyntaxError: unexpected EOF while parsing

# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
# %matplotlib 

import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

xs = np.linspace(0,3,101)
ys = np.linspace(0,3,101)
zs = 

ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
